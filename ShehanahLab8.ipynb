# %%
# A
import os

os.makedirs("lab_data/input",exist_ok=True)
os.makedirs("lab_data/output",exist_ok=True)
os.makedirs("lab_data/logs",exist_ok=True)

for item in os.listdir("lab_data"):
    print(item)

os.rename("lab_data/logs","lab_data/history")
# Out:
# input
# logs
# output

# %%
# A
import os

for item in os.listdir("lab_data"):
    path = os.path.join("lab_data", item)
    
    if os.path.isfile(path):
        print(item, "File")
    else:
        print(item, "Directory")
# Out:
# history Directory
# input Directory
# output Directory

# %%
# B
with open("lab_data/input/notes.txt", "w") as file:
    file.write("Line 1\n")
    file.write("Line 2\n")
    file.write("Line 3\n")
    file.write("Line 4\n")
    file.write("Line 5\n")

# %%
# B
with open("lab_data/input/notes.txt", "r") as file:
    lines = file.readlines()

print("Number of lines:", len(lines))
# Out:
# Number of lines: 5

# %%
# B
with open("lab_data/input/notes.txt", "r") as a:
    content = a.read()

with open("lab_data/output/summary.txt", "w") as b:
    b.write(content)

# %%
# C
import pyfiglet

text = pyfiglet.figlet_format("Shehanah")
print(text)
with open("lab_data/output/ascii.txt", "w") as file:
    file.write(text)
# Out:
#  ____  _          _                       _
# / ___|| |__   ___| |__   __ _ _ __   __ _| |__
# \___ \| '_ \ / _ \ '_ \ / _` | '_ \ / _` | '_ \
#  ___) | | | |  __/ | | | (_| | | | | (_| | | | |
# |____/|_| |_|\___|_| |_|\__,_|_| |_|\__,_|_| |_|

# %%
# D
os.rmdir("lab_data/history")
